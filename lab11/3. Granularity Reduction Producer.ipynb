# %%
# import statements
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import datetime as dt
import csv

#configuration
hostip = "192.168.100.4" #change me

def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, data)
        #print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'week11_orig_data'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    i=1
    while True:
        #generate object to be sent
        data = {'ts': int(dt.datetime.now().timestamp()), 'value': int(random.randrange(0,90))}
        print(data)
        
        publish_message(producer, topic, data)
        sleep(1)
        i+=1
        if i>100:
            i=1
# Out:
# Publishing records..
# {'ts': 1653646645, 'value': 34}
# {'ts': 1653646646, 'value': 42}
# {'ts': 1653646647, 'value': 25}
# {'ts': 1653646648, 'value': 26}
# {'ts': 1653646649, 'value': 83}
# {'ts': 1653646650, 'value': 30}
# {'ts': 1653646651, 'value': 89}
# {'ts': 1653646652, 'value': 48}
# {'ts': 1653646654, 'value': 28}
# {'ts': 1653646655, 'value': 26}
# {'ts': 1653646656, 'value': 54}
# {'ts': 1653646657, 'value': 85}
# {'ts': 1653646658, 'value': 30}
# {'ts': 1653646659, 'value': 4}
# {'ts': 1653646660, 'value': 35}
# {'ts': 1653646661, 'value': 71}
# {'ts': 1653646662, 'value': 51}
# {'ts': 1653646663, 'value': 30}
# {'ts': 1653646664, 'value': 41}
# {'ts': 1653646665, 'value': 0}
# {'ts': 1653646666, 'value': 44}
# {'ts': 1653646667, 'value': 71}
# {'ts': 1653646668, 'value': 7}
# {'ts': 1653646669, 'value': 78}
# {'ts': 1653646670, 'value': 77}
# {'ts': 1653646671, 'value': 49}
# {'ts': 1653646672, 'value': 3}
# {'ts': 1653646673, 'value': 36}
# {'ts': 1653646674, 'value': 14}
# {'ts': 1653646675, 'value': 41}
# {'ts': 1653646676, 'value': 33}
# {'ts': 1653646677, 'value': 76}
# {'ts': 1653646678, 'value': 6}
# {'ts': 1653646679, 'value': 24}
# {'ts': 1653646680, 'value': 38}
# {'ts': 1653646681, 'value': 6}
# {'ts': 1653646682, 'value': 70}
# {'ts': 1653646683, 'value': 4}
# {'ts': 1653646684, 'value': 31}
# {'ts': 1653646685, 'value': 33}
# {'ts': 1653646686, 'value': 61}
# {'ts': 1653646687, 'value': 78}
# {'ts': 1653646688, 'value': 40}
# {'ts': 1653646689, 'value': 59}
# {'ts': 1653646690, 'value': 37}
# {'ts': 1653646691, 'value': 86}
# {'ts': 1653646692, 'value': 88}
# {'ts': 1653646693, 'value': 47}
# {'ts': 1653646694, 'value': 2}
# {'ts': 1653646695, 'value': 54}
# {'ts': 1653646696, 'value': 69}
# {'ts': 1653646697, 'value': 10}
# {'ts': 1653646698, 'value': 32}
# {'ts': 1653646699, 'value': 0}
# {'ts': 1653646700, 'value': 73}
# {'ts': 1653646701, 'value': 52}
# {'ts': 1653646702, 'value': 56}
# {'ts': 1653646703, 'value': 82}
# {'ts': 1653646704, 'value': 74}
# {'ts': 1653646705, 'value': 49}
# {'ts': 1653646706, 'value': 82}
# {'ts': 1653646707, 'value': 49}
# {'ts': 1653646708, 'value': 79}
# {'ts': 1653646709, 'value': 20}
# {'ts': 1653646710, 'value': 26}
# {'ts': 1653646711, 'value': 66}
# {'ts': 1653646712, 'value': 80}
# {'ts': 1653646713, 'value': 16}
# {'ts': 1653646714, 'value': 52}
# {'ts': 1653646715, 'value': 29}
# {'ts': 1653646716, 'value': 5}
# {'ts': 1653646717, 'value': 35}
# {'ts': 1653646718, 'value': 8}
# {'ts': 1653646719, 'value': 35}
# {'ts': 1653646720, 'value': 82}
# {'ts': 1653646721, 'value': 11}
# {'ts': 1653646722, 'value': 20}
# {'ts': 1653646723, 'value': 42}
# {'ts': 1653646724, 'value': 45}
# {'ts': 1653646725, 'value': 44}
# {'ts': 1653646726, 'value': 28}
# {'ts': 1653646727, 'value': 42}
# {'ts': 1653646728, 'value': 42}
# {'ts': 1653646729, 'value': 15}
# {'ts': 1653646730, 'value': 0}
# {'ts': 1653646731, 'value': 48}
# {'ts': 1653646732, 'value': 88}
# {'ts': 1653646733, 'value': 50}
# {'ts': 1653646734, 'value': 75}
# {'ts': 1653646735, 'value': 52}
# {'ts': 1653646736, 'value': 45}
# {'ts': 1653646737, 'value': 46}
# {'ts': 1653646738, 'value': 65}
# {'ts': 1653646739, 'value': 42}
# {'ts': 1653646740, 'value': 68}
# {'ts': 1653646741, 'value': 13}
# {'ts': 1653646742, 'value': 12}
# {'ts': 1653646743, 'value': 65}
# {'ts': 1653646744, 'value': 17}
# {'ts': 1653646745, 'value': 75}
# {'ts': 1653646746, 'value': 3}
# {'ts': 1653646747, 'value': 82}
# {'ts': 1653646748, 'value': 2}
# {'ts': 1653646749, 'value': 8}
# {'ts': 1653646750, 'value': 72}
# {'ts': 1653646751, 'value': 9}
# {'ts': 1653646752, 'value': 84}
# {'ts': 1653646753, 'value': 81}
# {'ts': 1653646754, 'value': 52}
# {'ts': 1653646755, 'value': 7}
# {'ts': 1653646756, 'value': 81}
# {'ts': 1653646757, 'value': 20}
# {'ts': 1653646758, 'value': 75}
